# %% [markdown]
# # Pandas Library
# Pandas is a library used for data manipulation and analysis. Pandas offers data structures and operations for creating and manipulating Data [Series](http://pandas.pydata.org/pandas-docs/dev/generated/pandas.Series.html) and [DataFrame](http://pandas.pydata.org/pandas-docs/dev/generated/pandas.DataFrame.html) objects. Data can be imported from various data sources, e.g., [Numpy](http://www.numpy.org/) arrays, Python dictionaries and CSV files. Pandas allows you to manipulate, organize and display the data.
# <div class="alert alert-block alert-info" style="margin-top: 20px">**Note:**
# This cookbook is based on the examples and tutorials from the [Pandas Homepage](http://pandas.pydata.org).
# </div>

# %% [markdown]
# # Setup

# %%
#<help:pandas_setup>
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python2.7/dist-packages (0.23.1)
# Requirement already satisfied: numpy>=1.9.0 in /usr/local/lib/python2.7/dist-packages (from pandas) (1.14.5)
# Requirement already satisfied: python-dateutil>=2.5.0 in /usr/local/lib/python2.7/dist-packages (from pandas) (2.7.3)
# Requirement already satisfied: pytz>=2011k in /usr/local/lib/python2.7/dist-packages (from pandas) (2018.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python2.7/dist-packages (from python-dateutil>=2.5.0->pandas) (1.11.0)

# %%
#<help:pandas_setup>
import pandas as pd
pd.__version__
# Out:
# u'0.23.1'

# %% [markdown]
# # Series
# Series are one dimensional arrays capable of holding any array type. The axis labels are known as the **index**. The index must be the same length as the amount of values passed. Pass a list of values to a series.

# %%
#<help:series_create>
import pandas as pd
import numpy as np
s = pd.Series([1.5,3,5,np.nan,5,9])
s
# Out:
# 0    1.5
# 1    3.0
# 2    5.0
# 3    NaN
# 4    5.0
# 5    9.0
# dtype: float64

# %% [markdown]
# # DataFrames
# A DataFrame is two-dimensional. Columns can be of different data types.
# DataFrames accept many data inputs including series and other DataFrames.
# You can pass indexes (row labels) and columns (column labels). Indexes can be numbers, dates, or strings/tuples.

# %%
#<help:dataframe_create>
import pandas as pd
dates = pd.date_range('20140102',periods=4)
dates
# Out:
# DatetimeIndex(['2014-01-02', '2014-01-03', '2014-01-04', '2014-01-05'], dtype='datetime64[ns]', freq='D')

# %% [markdown]
# Create the DataFrame by adding the values, set the index and columns.

# %%
#<help:dataframe_create>
import pandas as pd
import numpy as np
dates = pd.date_range('20140102',periods=4)
df = pd.DataFrame(np.random.randn(4,5),index=dates,columns=list('ABCDE'))
df
# Out:
#                    A         B         C         D         E
# 2014-01-02  2.171028 -1.104273  0.235812  0.020899 -0.117580
# 2014-01-03  0.404578  0.582968 -1.564433  0.270082  0.512003
# 2014-01-04  0.070578  0.311075 -1.286216  0.049392  0.541896
# 2014-01-05  0.203439 -1.100781  0.482934 -0.710208 -0.055346

# %% [markdown]
# ## Head
# View the top rows of a DataFrame with `head()`. You can configure the number of rows that `head` shows by passing a parameter value. The default (without parameter) is `5`.

# %%
#<help:dataframe_head>
import pandas as pd
import numpy as np
dates = pd.date_range('20140402',periods=6)
df = pd.DataFrame(np.random.randn(6,5),index=dates,columns=list('ABCDE'))
df.head()
# Out:
#                    A         B         C         D         E
# 2014-04-02 -0.187031 -1.305206  0.063388 -0.537147 -1.975741
# 2014-04-03 -0.069657 -0.818150 -0.238379  1.759429 -1.097986
# 2014-04-04 -1.174045  0.948019 -1.651937  0.352084 -0.914028
# 2014-04-05 -0.439248  0.796922 -0.874644 -0.206083  0.625106
# 2014-04-06 -0.794017  0.353013 -0.429723 -0.183216  0.475452

# %% [markdown]
# ## Tail
# View the bottom rows of the DataFrame with `tail()`.  You can configure the number of rows that `tail` shows by passing a parameter value. The default (without parameter) is `5`.

# %%
#<help:dataframe_tail>
import pandas as pd
import numpy as np
dates = pd.date_range('20140501',periods=6)
df = pd.DataFrame(np.random.randn(6,5),index=dates,columns=list('ABCDE'))
df.tail()
# Out:
#                    A         B         C         D         E
# 2014-05-02  0.222867 -0.912421 -0.351527 -0.538221 -0.701799
# 2014-05-03  1.481119  0.035070 -1.022558 -0.095358 -1.470548
# 2014-05-04 -2.361931  1.312890 -0.219226  1.271726 -0.758201
# 2014-05-05 -0.874228  1.018413  1.355338  0.441828  0.080595
# 2014-05-06 -0.384438  0.320735 -0.791535 -2.031012  2.470081

# %% [markdown]
# ## Index, Columns, and Values
# See the index, columns, and values with `data_frame.index`, `data_frame.columns` and `data_frame.values` respectively.

# %%
#<help:dataframe_index>
import pandas as pd
import numpy as np
dates = pd.date_range('20140102',periods=4)
df = pd.DataFrame(np.random.randn(4,5),index=dates,columns=list('ABCDE'))
df.index
# Out:
# DatetimeIndex(['2014-01-02', '2014-01-03', '2014-01-04', '2014-01-05'], dtype='datetime64[ns]', freq='D')

# %% [markdown]
# For specific values:

# %%
#<help:dataframe_columns>
import pandas as pd
import numpy as np
dates = pd.date_range('20140102',periods=4)
df = pd.DataFrame(np.random.randn(4,5),index=dates,columns=list('ABCDE'))
df.columns
# Out:
# Index([u'A', u'B', u'C', u'D', u'E'], dtype='object')

# %%
#<help:dataframe_values>
import pandas as pd
import numpy as np
dates = pd.date_range('20140102',periods=4)
df = pd.DataFrame(np.random.randn(4,5),index=dates,columns=list('ABCDE'))
df.values
# Out:
# array([[-0.00716837,  1.00762863, -0.6635703 ,  0.36827933, -0.58997814],
#        [-1.44794671,  1.20100789, -1.36374546,  0.51530236, -0.63896737],
#        [ 1.03776466, -0.15121153,  0.72012914,  0.57786764,  0.99936981],
#        [-0.25296027, -0.38396842,  0.51266751, -0.21827767, -1.02361191]])

# %% [markdown]
# ## Describe Statistics
# Use `.describe()` to display the mean, median, variance etc. of the data in your DataFrame.

# %%
#<help:dataframe_describe>
import pandas as pd
import numpy as np
dates = pd.date_range('20140102',periods=4)
df = pd.DataFrame(np.random.randn(4,5),index=dates,columns=list('ABCDE'))
df.describe()
# Out:
#               A         B         C         D         E
# count  4.000000  4.000000  4.000000  4.000000  4.000000
# mean   0.732518  0.818967  0.606163 -0.883236 -0.377747
# std    1.287276  0.404708  0.968464  0.396466  0.416095
# min   -0.970945  0.375815 -0.605265 -1.259175 -0.822038
# 25%    0.363093  0.594223  0.313361 -1.202786 -0.677384
# 50%    0.873417  0.782896  0.632102 -0.901207 -0.375345
# 75%    1.242842  1.007640  0.924905 -0.581657 -0.075708
# max    2.154183  1.334260  1.765710 -0.471355  0.061741

# %% [markdown]
# ## Transpose Data
# Transpose rows and columns easily using `DataFrame.T`.

# %%
#<help:dataframe_transpose>
import pandas as pd
import numpy as np
dates = pd.date_range('20140102',periods=4)
df = pd.DataFrame(np.random.randn(4,5),index=dates,columns=list('ABCDE'))
df.T
# Out:
#    2014-01-02  2014-01-03  2014-01-04  2014-01-05
# A    0.176629    0.527509    0.529078    0.272235
# B   -0.201545   -0.634896   -0.478087   -1.296541
# C    1.222227   -0.872263    0.070147    0.729388
# D   -2.262443    1.009612   -0.631027    0.443272
# E    2.177270    0.349694   -0.424493   -1.330241

# %% [markdown]
# ## Sort by Index

# %%
#<help:dataframe_sort_index>
import pandas as pd
import numpy as np
dates = pd.date_range('20140102',periods=4)
df = pd.DataFrame(np.random.randn(4,5),index=dates,columns=list('ABCDE'))
df.sort_index(axis=1, ascending=True)
# Out:
#                    A         B         C         D         E
# 2014-01-02 -1.794364  0.121660  0.883160  0.627325 -0.648805
# 2014-01-03  0.180951 -0.737121 -0.376455 -0.811580 -2.422564
# 2014-01-04 -1.272297  1.606311  1.019177  1.096128  0.296544
# 2014-01-05 -0.862296  0.392076  0.302725  0.093916 -1.381547

# %% [markdown]
# ## Sort by Columns

# %%
#<help:dataframe_sort_columns>
import pandas as pd
import numpy as np
dates = pd.date_range('20140102',periods=4)
df = pd.DataFrame(np.random.randn(4,5),index=dates,columns=list('ABCDE'))
df.sort(columns='B')
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-14-a3543a3afa5b> in <module>()
#       4 dates = pd.date_range('20140102',periods=4)
#       5 df = pd.DataFrame(np.random.randn(4,5),index=dates,columns=list('ABCDE'))
# ----> 6 df.sort(columns='B')
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    4370             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4371                 return self[name]
# -> 4372             return object.__getattribute__(self, name)
#    4373
#    4374     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'sort'

# %% [markdown]
# # Selection
# Find and select data, slice, locate by columns or values. These operations make pandas very similar to SQL in terms of querying information. The `.loc` attribute is the primary access method. The following are valid inputs:
#
# * A single label, e.g. `5` or 'a' (Note that `5` is interpreted as a label of the index. This use is not an integer position along the index.)
# * A list or array of labels ['a', 'b', 'c']
# * A slice object with labels 'a':'f' (note that contrary to usual python slices, both the start and the stop are included!)
# * A boolean array

# %% [markdown]
# ## Select
# Select columns by label.

# %%
#<help:dataframe_select_cols>
import pandas as pd
import numpy as np
dates = pd.date_range('20140102',periods=4)
df = pd.DataFrame(np.random.randn(4,5),index=dates,columns=list('ABCDE'))
df[['A','E']]
# Out:
#                    A         E
# 2014-01-02 -0.286614 -1.502349
# 2014-01-03 -0.103061 -1.416838
# 2014-01-04  0.587642 -0.182978
# 2014-01-05  0.540073 -0.235372

# %% [markdown]
# Select row by label.

# %%
#<help:dataframe_select_row>
import pandas as pd
import numpy as np
dates = pd.date_range('20140102',periods=4)
df = pd.DataFrame(np.random.randn(4,5),index=dates,columns=list('ABCDE'))
df.loc['20140102']
# Out:
# A    0.964146
# B   -0.136329
# C   -1.185491
# D   -0.605025
# E   -0.063995
# Name: 2014-01-02 00:00:00, dtype: float64

# %% [markdown]
# Selection row by index.

# %%
#<help:dataframe_select_row_pos>
import pandas as pd
import numpy as np
dates = pd.date_range('20140102',periods=4)
df = pd.DataFrame(np.random.randn(4,5),index=dates,columns=list('ABCDE'))
df.iloc[3]
# Out:
# A    0.671442
# B    2.089431
# C   -1.216076
# D   -0.696305
# E   -0.896740
# Name: 2014-01-05 00:00:00, dtype: float64

# %% [markdown]
# Select row and columns by labels.

# %%
#<help:dataframe_select_row_col>
import pandas as pd
import numpy as np
dates = pd.date_range('20140102',periods=4)
df = pd.DataFrame(np.random.randn(4,5),index=dates,columns=list('ABCDE'))
df.loc['20140102','E']
# Out:
# 0.4327698548504004

# %%
#<help:dataframe_select_row_col_pos>
import pandas as pd
import numpy as np
dates = pd.date_range('20140102',periods=4)
df = pd.DataFrame(np.random.randn(4,5),index=dates,columns=list('ABCDE'))
df.iloc[1,1]
# Out:
# 1.1958318534500236

# %%
#<help:dataframe_select_row_col_pos>
import pandas as pd
import numpy as np
dates = pd.date_range('20140102',periods=4)
df = pd.DataFrame(np.random.randn(4,5),index=dates,columns=list('ABCDE'))
df.iat[1,1]
# Out:
# -2.81746882357076

# %%
#<help:dataframe_select_row_cols>
import pandas as pd
import numpy as np
dates = pd.date_range('20140102',periods=4)
df = pd.DataFrame(np.random.randn(4,5),index=dates,columns=list('ABCDE'))
df.loc['20140102',['A','D']]
# Out:
# A    1.133848
# D    1.460613
# Name: 2014-01-02 00:00:00, dtype: float64

# %%
#<help:dataframe_select_rows_cols_pos>
import pandas as pd
import numpy as np
dates = pd.date_range('20140102',periods=4)
df = pd.DataFrame(np.random.randn(4,5),index=dates,columns=list('ABCDE'))
df.iloc[[1,2,3],[0,2]]
# Out:
#                    A         C
# 2014-01-03 -0.654680 -0.143851
# 2014-01-04 -0.567571  1.236376
# 2014-01-05  0.425415 -0.893784

# %% [markdown]
# ## Slice
# Select rows of a DataFrame by slicing.

# %%
#<help:dataframe_slice_rows>
import pandas as pd
import numpy as np
dates = pd.date_range('20140102',periods=4)
df = pd.DataFrame(np.random.randn(4,5),index=dates,columns=list('ABCDE'))
df[1:4]
# Out:
#                    A         B         C         D         E
# 2014-01-03  0.614564 -1.008096 -1.880024  1.531471  0.919681
# 2014-01-04  0.238756  1.346867  0.377046 -0.451865 -0.855126
# 2014-01-05  0.537262  0.844460 -0.025261 -2.787334  1.470442

# %%
#<help:dataframe_slice_rows_cols>
import pandas as pd
import numpy as np
dates = pd.date_range('20140102',periods=4)
df = pd.DataFrame(np.random.randn(4,5),index=dates,columns=list('ABCDE'))
df.loc[:,['B','D']]
# Out:
#                    B         D
# 2014-01-02  0.549109  1.594328
# 2014-01-03 -0.698654 -0.373939
# 2014-01-04 -0.230132  0.898916
# 2014-01-05  0.027259 -1.205256

# %%
#<help:dataframe_slice_rows_cols>
import pandas as pd
import numpy as np
dates = pd.date_range('20140102',periods=4)
df = pd.DataFrame(np.random.randn(4,5),index=dates,columns=list('ABCDE'))
df.loc['20140102':'20140104',['B','E']]
# Out:
#                    B         E
# 2014-01-02 -0.393072  1.609309
# 2014-01-03  0.162253 -0.653457
# 2014-01-04 -1.163857 -1.575779

# %% [markdown]
# Slice rows and columns by index value.

# %%
#<help:dataframe_slice_rows_cols_pos>
import pandas as pd
import numpy as np
dates = pd.date_range('20140102',periods=4)
df = pd.DataFrame(np.random.randn(4,5),index=dates,columns=list('ABCDE'))
df.iloc[1:3,:]
# Out:
#                    A         B         C         D         E
# 2014-01-03 -2.287059  0.837602  1.248572 -0.139839 -0.151435
# 2014-01-04 -1.507583  1.182833  2.105683  0.736880 -0.799070

# %%
#<help:dataframe_slice_rows_cols_pos>
import pandas as pd
import numpy as np
dates = pd.date_range('20140102',periods=4)
df = pd.DataFrame(np.random.randn(4,5),index=dates,columns=list('ABCDE'))
df.iloc[:,1:3]
# Out:
#                    B         C
# 2014-01-02  0.923885  0.856145
# 2014-01-03 -1.699956 -1.666803
# 2014-01-04 -0.487439 -0.295220
# 2014-01-05  0.356209 -0.354342

# %%
#<help:dataframe_slice_rows_cols_pos>
import pandas as pd
import numpy as np
dates = pd.date_range('20140102',periods=4)
df = pd.DataFrame(np.random.randn(4,5),index=dates,columns=list('ABCDE'))
df.iloc[3:4,0:2]
# Out:
#                    A         B
# 2014-01-05 -0.427835 -1.258108

# %% [markdown]
# ## Index
# Filter DataFrame contents using vector masks.

# %% [markdown]
# Filter DataFrame using logical expressions.

# %%
#<help:dataframe_index_boolean>
import pandas as pd
import numpy as np
dates = pd.date_range('20140102',periods=4)
df = pd.DataFrame(np.random.randn(4,5),index=dates,columns=list('ABCDE'))
df[df.A > 0]
# Out:
#                    A         B         C         D         E
# 2014-01-02  0.957635  1.335083  0.855984  0.612588 -0.614967
# 2014-01-03  0.633994  0.591557  2.427961 -0.325587  0.791013
# 2014-01-04  1.579315  0.849582  0.385014 -1.189923  0.154053
# 2014-01-05  0.629541  0.873079  1.558823  0.188650 -0.515623

# %%
#<help:dataframe_index_boolean>
import pandas as pd
import numpy as np
dates = pd.date_range('20140102',periods=4)

df = pd.DataFrame({'A' : ['foo', 'bar', 'foo', 'bar', 'foo', 'bar', 'foo', 'foo'],
                'B' : ['one', 'one', 'two', 'three', 'two', 'two', 'one', 'three'],
                'C' : np.random.randn(8), 'D' : np.random.randn(8)})

df[df['A'] == 'foo']
# Out:
#      A      B         C         D
# 0  foo    one -0.226716  2.046289
# 2  foo    two  0.610462  0.462538
# 4  foo    two  0.258423  0.179931
# 6  foo    one  0.946826  1.142152
# 7  foo  three  2.024321 -1.305640

# %% [markdown]
# Filter DataFrame using multiple logical expressions.

# %%
#<help:dataframe_index_boolean_multiple>
import pandas as pd
import numpy as np
dates = pd.date_range('20140102',periods=4)

df = pd.DataFrame({'A' : ['foo', 'bar', 'foo', 'bar', 'foo', 'bar', 'foo', 'foo'],
                'B' : ['one', 'one', 'two', 'three', 'two', 'two', 'one', 'three'],
                'C' : np.random.randn(8), 'D' : np.random.randn(8)})

df[(df['A'] == 'foo') & (df['B'] == 'one')]
# Out:
#      A    B         C         D
# 0  foo  one -0.051985 -0.464010
# 6  foo  one -1.170160 -0.085493

# %% [markdown]
# ## Built-in Methods

# %% [markdown]
# Filter DataFrame using `isin` method.

# %%
#<help:dataframe_index_isin>
import pandas as pd
import numpy as np
dates = pd.date_range('20140102',periods=4)

df = pd.DataFrame({'A' : ['foo', 'bar', 'foo', 'bar', 'foo', 'bar', 'foo', 'foo'],
                'B' : ['one', 'one', 'two', 'three', 'two', 'two', 'one', 'three'],
                'C' : np.random.randn(8), 'D' : np.random.randn(8)})

df[df['B'].isin(['two','three'])]
# Out:
#      A      B         C         D
# 2  foo    two  0.050408 -0.202770
# 3  bar  three -0.169966 -0.756154
# 4  foo    two -0.074127  0.816337
# 5  bar    two -0.639608 -1.221994
# 7  foo  three -0.928548  1.324442

# %% [markdown]
# # Assignment
# Assign vector values to DataFrame columns.

# %%
#<help:dataframe_assign_col>
import pandas as pd
import numpy as np
dates = pd.date_range('20140102',periods=4)
df = pd.DataFrame(np.random.randn(4,5),index=dates,columns=list('ABCDE'))
df['F'] = pd.Series([1,2,3,4],index=pd.date_range('20140102',periods=4))
df
# Out:
#                    A         B         C         D         E  F
# 2014-01-02  0.506637 -0.618277 -2.726108  0.005192 -0.664517  1
# 2014-01-03  0.784236  1.149006  2.111611 -2.327951 -1.479067  2
# 2014-01-04  0.611131  0.426573  1.922665 -0.700720  0.925818  3
# 2014-01-05 -0.660166  0.695310 -2.052677  0.457195 -0.323312  4

# %%
#<help:dataframe_assign_col>
import pandas as pd
import numpy as np
dates = pd.date_range('20140102',periods=4)
df = pd.DataFrame(np.random.randn(4,5),index=dates,columns=list('ABCDE'))
df.loc[:,'D'] = np.array([5] * len(df))
df
# Out:
#                    A         B         C  D         E
# 2014-01-02 -0.989343 -1.136709  0.179368  5 -1.089153
# 2014-01-03 -0.469706 -0.954536  0.128623  5  1.097322
# 2014-01-04 -0.480614  1.186407 -0.756885  5 -0.075926
# 2014-01-05  0.140918  0.565769 -0.462560  5  0.826344

# %%
#<help:dataframe_assign_row_col>
import pandas as pd
import numpy as np
dates = pd.date_range('20140102',periods=4)
df = pd.DataFrame(np.random.randn(4,5),index=dates,columns=list('ABCDE'))
df.at[dates[0],'B'] = 0
df
# Out:
#                    A        B         C         D         E
# 2014-01-02 -0.567475  0.00000  2.259183 -0.330616  0.597864
# 2014-01-03 -1.037807  0.14909  1.824347 -1.228042 -2.088032
# 2014-01-04  1.081901  0.14882  0.903117  0.047050 -0.685420
# 2014-01-05  0.605104 -0.02778 -0.994409  1.380434 -0.619622

# %%
#<help:dataframe_assign_row_col_pos>
import pandas as pd
import numpy as np
dates = pd.date_range('20140102',periods=4)
df = pd.DataFrame(np.random.randn(4,5),index=dates,columns=list('ABCDE'))
df.iat[0,1] = 0
df
# Out:
#                    A         B         C         D         E
# 2014-01-02 -0.163182  0.000000  0.508718  1.039148  0.522165
# 2014-01-03  0.804333  1.022212  0.062480  0.291492  0.946421
# 2014-01-04  2.830401 -0.216336 -0.929279  0.166181  0.658317
# 2014-01-05 -0.710491 -1.489895 -1.742598  0.844914 -0.142362

# %% [markdown]
# # Missing Data

# %% [markdown]
# Drop rows that have missing data.

# %%
#<help:dataframe_dropna>
import pandas as pd
import numpy as np
dates = pd.date_range('20140102',periods=4)
df = pd.DataFrame(np.random.randn(4,5),index=dates,columns=list('ABCDE'))
df.loc[dates[0]:dates[1],['D','E']] = float('nan')
df.dropna()
# Out:
#                    A         B         C         D         E
# 2014-01-04  0.541713 -0.648701  0.724113  0.801661 -1.344199
# 2014-01-05  1.145477  1.173221 -0.029572 -0.047736  0.239020

# %% [markdown]
# Set the value of cells that have missing data.

# %%
#<help:dataframe_fillna>
import pandas as pd
import numpy as np
dates = pd.date_range('20140102',periods=4)
df = pd.DataFrame(np.random.randn(4,5),index=dates,columns=list('ABCDE'))
df.loc[dates[0]:dates[1],['D','E']] = float('nan')
df.fillna(value=0)
# Out:
#                    A         B         C         D         E
# 2014-01-02 -1.709435  0.366690 -0.116141  0.000000  0.000000
# 2014-01-03 -1.835911  0.236217 -1.161010  0.000000  0.000000
# 2014-01-04  0.366024  0.373947 -0.513208  0.497217 -0.832813
# 2014-01-05 -1.043086 -1.880128  1.197687  0.127268  0.430143

# %% [markdown]
# List cells where data is missing.

# %%
#<help:dataframe_isnull>
import pandas as pd
import numpy as np
dates = pd.date_range('20140102',periods=4)
df = pd.DataFrame(np.random.randn(4,5),index=dates,columns=list('ABCDE'))
df.loc[dates[0]:dates[1],['D','E']] = float('nan')
pd.isnull(df)
# Out:
#                 A      B      C      D      E
# 2014-01-02  False  False  False   True   True
# 2014-01-03  False  False  False   True   True
# 2014-01-04  False  False  False  False  False
# 2014-01-05  False  False  False  False  False

# %% [markdown]
# # Append

# %%
#<help:dataframe_append_rows>
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.randn(8, 4), columns=['A','B','C','D'])
# duplicate last row
df.append(df.iloc[-1], ignore_index=True)
# Out:
#           A         B         C         D
# 0  0.154985  0.366228 -0.070029  0.818530
# 1  0.932778 -1.310638 -0.011582 -0.539333
# 2 -0.590783  0.269848 -1.122791 -0.762396
# 3  0.679876  0.359851  0.050149 -0.887887
# 4  1.108602 -0.089626  1.381314  0.941064
# 5 -0.609481 -0.966639  0.003591 -1.717991
# 6  0.403402 -0.088966 -0.171610  0.510507
# 7 -0.301456 -0.068413  0.233525  0.386147
# 8 -0.301456 -0.068413  0.233525  0.386147

# %% [markdown]
# # Groupby
#
# * **Splitting** the data into groups based on some criteria
#
# * **Applying** a function to each group independently
#
# * **Combining** the results into a data structure

# %%
#<help:dataframe_groupby>
import pandas as pd
import numpy as np
dates = pd.date_range('20140102',periods=4)
df = pd.DataFrame({'A' : ['foo', 'bar', 'foo', 'bar', 'foo', 'bar', 'foo', 'foo'],
                'B' : ['one', 'one', 'two', 'three', 'two', 'two', 'one', 'three'],
                'C' : np.random.randn(8), 'D' : np.random.randn(8)})
print df
df.groupby('A').groups
# Out:
#      A      B         C         D
# 0  foo    one -2.746203  0.934171
# 1  bar    one  0.162436  0.305460
# 2  foo    two  0.774100 -0.781778
# 3  bar  three  0.186506  0.127446
# 4  foo    two  0.206602  1.142748
# 5  bar    two  1.118154 -0.682721
# 6  foo    one -1.293360  1.510303
# 7  foo  three -1.038141 -0.089564
# {'bar': Int64Index([1, 3, 5], dtype='int64'),
#  'foo': Int64Index([0, 2, 4, 6, 7], dtype='int64')}

# %%
#<help:dataframe_groupby_multiple>
import pandas as pd
import numpy as np
dates = pd.date_range('20140102',periods=4)
df = pd.DataFrame({'A' : ['foo', 'bar', 'foo', 'bar', 'foo', 'bar', 'foo', 'foo'],
                'B' : ['one', 'one', 'two', 'three', 'two', 'two', 'one', 'three'],
                'C' : np.random.randn(8), 'D' : np.random.randn(8)})
print df
df.groupby(['A','B']).groups
# Out:
#      A      B         C         D
# 0  foo    one -0.329746 -0.514742
# 1  bar    one  0.671707 -0.216012
# 2  foo    two  1.098634 -1.431221
# 3  bar  three  0.985156  1.280691
# 4  foo    two  0.838115 -1.300421
# 5  bar    two  0.498575  1.098548
# 6  foo    one -1.829077 -0.165700
# 7  foo  three  2.232222  0.947085
# {('bar', 'one'): [1],
#  ('bar', 'three'): [3],
#  ('bar', 'two'): [5],
#  ('foo', 'one'): [0, 6],
#  ('foo', 'three'): [7],
#  ('foo', 'two'): [2, 4]}

# %% [markdown]
# Group by a column and compute cumulative sum.

# %%
#<help:dataframe_groupby_sum>
import pandas as pd
import numpy as np
dates = pd.date_range('20140102',periods=4)
df = pd.DataFrame({'A' : ['foo', 'bar', 'foo', 'bar', 'foo', 'bar', 'foo', 'foo'],
                'B' : ['one', 'one', 'two', 'three', 'two', 'two', 'one', 'three'],
                'C' : np.random.randn(8), 'D' : np.random.randn(8)})
df.groupby('A').sum()
# Out:
#             C         D
# A
# bar  0.782669  0.743121
# foo  0.884809 -2.353555

# %% [markdown]
# Group multiple columns and add them.

# %%
#<help:dataframe_groupby_multiple_sum>
import pandas as pd
import numpy as np
dates = pd.date_range('20140102',periods=4)
df = pd.DataFrame({'A' : ['foo', 'bar', 'foo', 'bar', 'foo', 'bar', 'foo', 'foo'],
                'B' : ['one', 'one', 'two', 'three', 'two', 'two', 'one', 'three'],
                'C' : np.random.randn(8), 'D' : np.random.randn(8)})
df.groupby(['A','B']).sum()
# Out:
#                   C         D
# A   B
# bar one   -0.457317  0.399048
#     three  2.013467  2.824962
#     two   -0.793164 -0.783425
# foo one   -0.050579  0.402122
#     three -1.102993  0.301112
#     two    1.369225  1.014482

# %% [markdown]
# # File Management

# %% [markdown]
# ## Save to CSV
# Use the `to_csv` function to save a DataFrame to a `csv` or `txt` file.  The full parameter list is in the [documentation](http://pandas.pydata.org/pandas-docs/version/0.15.1/generated/pandas.DataFrame.to_csv.html).

# %%
#<help:to_csv>
import pandas as pd
import numpy as np
names = ['Michael','Jessica','Mary','John','Ashley']
births = [1168, 255, 177, 878, 973]
df = pd.DataFrame(data=zip(names,births), columns=['Name', 'Births'])
print df
df.to_csv('births.csv',index=False,header=False)
# Out:
#       Name  Births
# 0  Michael    1168
# 1  Jessica     255
# 2     Mary     177
# 3     John     878
# 4   Ashley     973

# %% [markdown]
# ## Read from CSV
# Use the `read_csv` function to read from a csv or text file.  By default, `read_csv` assumes that the fields are comma-separated. If the data is indexed, you can select the column to be used as an index, eg. `index_col=0`. The complete parameter list is in the [documentation](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.io.parsers.read_csv.html).

# %%
#<help:read_csv>
import pandas as pd
import numpy as np

# write DataFrame to file
names = ['Michael','Jessica','Mary','John','Ashley']
births = [1168, 255, 177, 878, 973]
df = pd.DataFrame(data=zip(names,births), columns=['Name', 'Births'])
df.to_csv('births.csv', index=False, header=False)

# now read it
pd.read_csv('births.csv', header=None, names=['Name','Births'])
# Out:
#       Name  Births
# 0  Michael    1168
# 1  Jessica     255
# 2     Mary     177
# 3     John     878
# 4   Ashley     973

# %% [markdown]
# ## Parsing Dates
# To facilitate working with dates data, `read_csv()` and `read_table()`, use the keyword arguments `parse_dates` and `date_parser` to allow users to specify a variety of columns and date/time formats to turn the input text data into datetime objects.

# %%
#<help:read_csv_dates>
import pandas as pd
import numpy as np
dates = pd.date_range('20140102',periods=5)
df = pd.DataFrame(np.random.randn(5,5), index=dates, columns=list('ABCDE'))
# specify dates column (defaults to first column) as index
djs = df.to_csv('dates.csv', index=True, header=True)

pd.read_csv('dates.csv', parse_dates=True, index_col=0)
# Out:
#                    A         B         C         D         E
# 2014-01-02  1.230553 -0.021946  1.030829 -0.434123 -0.830564
# 2014-01-03  0.142672  1.579765  0.790214 -0.709677  0.946231
# 2014-01-04  0.681243  0.101087 -0.953153 -0.900731 -0.132839
# 2014-01-05  0.107382 -0.770345  0.491117 -0.650824 -0.460996
# 2014-01-06 -1.106946 -0.681893 -0.488200 -0.763802 -0.161040

# %% [markdown]
# ## Save to JSON
# A Series or DataFrame can be converted to a valid JSON string. Use `to_json` with optional parameters:
#
# * `path_or_buf` : the pathname or buffer to write the output. This can be `None` in which case a JSON string is returned.
#
# * `orient` :
#
#     Series :
#         * default is index
#         * allowed values are {split, records, index}
#     DataFrame
#         * default is columns
#         * allowed values are {split, records, index, columns, values}
#     The format of the JSON string:
#
#
# |  command         |       params                                                            |
# |-----------|-----------|
# |`split`	|dict like {index -> [index], columns -> [columns], data -> [values]}|
# |`records`	|list like [{column -> value}, ... , {column -> value}]|
# |`index`	|dict like {index -> {column -> value}}|
# |`columns`	|dict like {column -> {index -> value}}|
# |`values`	|just the values array|
#
# * `date_format` : string, type of date conversion, ‘epoch’ for timestamp, ‘iso’ for ISO8601.
#
# * `double_precision` : The number of decimal places to use when encoding floating point values, default is 10.
#
# * `force_ascii` : force encoded string to be ASCII, default is True.
#
# * `date_unit` : The time unit to encode to, governs timestamp and ISO8601 precision. One of ‘s’, ‘ms’, ‘us’ or ‘ns’ for seconds, milliseconds, microseconds and nanoseconds respectively. Default is ‘ms’.
#
# * `efault_handler` : The handler to call if an object cannot otherwise be converted to a suitable format for JSON. Takes a single argument, which is the object to convert, and returns a serializable object.

# %%
#<help:to_json>
import pandas as pd
import numpy as np
dfj = pd.DataFrame(np.random.randn(5, 2), columns=list('AB'))
print dfj
dfj.to_json('random.json')
# Out:
#           A         B
# 0 -2.498614 -0.208938
# 1 -0.233480  0.590931
# 2 -1.284375 -1.681186
# 3 -2.318794  0.120668
# 4  0.578566 -0.611527

# %% [markdown]
# ## Read JSON
#
# **The same applies for reading a JSON file**. The most important [parameters](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.to_json.html) are:
#
# * `convert_dates` : a list of columns to parse for dates; If True, then try to parse date-like columns, default is `True`.
#
# * `eep_default_dates` : boolean, default `True`. If parsing dates, then parse the default date-like columns.
#
# * `numpy` : direct decoding to numpy arrays. default is False; Supports numeric data only, although labels may be non-numeric. Also note that the JSON ordering MUST be the same for each term if `numpy=True`.
#
# * `precise_float` : boolean, default False. Set to enable usage of higher precision (strtod) function when decoding string to double values. Default (`False`) is to use fast but less precise builtin functionality.
#
# * `ate_unit` : string, the timestamp unit to detect if converting dates. Default is `None`. By default the timestamp precision will be detected. If this is not desired then pass one of `‘s’, ‘ms’, ‘us’` or `‘ns’` to force timestamp precision to seconds, milliseconds, microseconds or nanoseconds respectively.

# %%
#<help:read_json>
import pandas as pd
import numpy as np
jsondf = pd.read_json('random.json')
jsondf
# Out:
#           A         B
# 0 -2.498614 -0.208938
# 1 -0.233480  0.590931
# 2 -1.284375 -1.681186
# 3 -2.318794  0.120668
# 4  0.578566 -0.611527

# %% [markdown]
# ##Pickling
# All pandas objects are equipped with `to_pickle` methods which use Python’s `cPickle` module to save data structures to disk using the pickle format.
# The `read_pickle` function in the pandas namespace can be used to load any pickled pandas object (or any other pickled object) from file.

# %%
#<help:read_pickle>
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.randn(5,5), index=None, columns=list('ABCDE'))
df.to_pickle('foo.pkl')
pd.read_pickle('foo.pkl')
# Out:
#           A         B         C         D         E
# 0  1.199409  1.289223  1.825797 -1.314374  0.335303
# 1  0.303126 -0.707643 -1.132780  0.074107 -0.232532
# 2 -0.053241  1.567699  0.636850  0.090190  0.616966
# 3 -1.497118  0.348553 -1.922327 -0.528003 -0.908313
# 4 -0.012853  0.706344 -0.816539  1.074067 -0.225220

# %% [markdown]
# # SQL Queries
# The `pandas.io.sql` module provides a collection of query wrappers to both facilitate data retrieval and to reduce dependencies on DB-specific APIs. Database abstraction is provided by SQLAlchemy, which needs to be installed. In addition you will need a driver library for your database.
#
# The key functions are:
#
# | Function                                       | Description                                          |
# |------------------------------------------------|------------------------------------------------------|
# |read_sql_table(table_name, con[, schema, ...])	 |Read SQL database table into a DataFrame.             |
# |read_sql_query(sql, con[, index_col, ...])      |Read SQL query into a DataFrame.                      |
# |read_sql(sql, con[, index_col, ...])	         |Read SQL query or database table into a DataFrame.    |
# |DataFrame.to_sql(name, con[, flavor, ...])      |Write records stored in a DataFrame to a SQL database.|

# %% [markdown]
# ## Setup

# %%
#<help:sql_setup>
# !pip install SQLAlchemy
# Out:
# Requirement already satisfied (use --upgrade to upgrade): SQLAlchemy in /home/notebook/ka_env/lib/python2.7/site-packages
# Cleaning up...

# %% [markdown]
# ## Query

# %%
#<help:sql_query>
import pandas as pd
import numpy as np
from sqlalchemy import create_engine

engine = create_engine('sqlite:///:memory:')
connection = engine.raw_connection()

df = pd.DataFrame(np.random.randn(5,5), index=None, columns=list('ABCDE'))
df.to_sql('data', connection)
pd.read_sql('SELECT * FROM data', connection)
# Out:
#    index         A         B         C         D         E
# 0      0 -2.906839 -0.686458 -1.966558  1.627646  0.483598
# 1      1 -0.288679 -1.267342  1.113767  0.540303 -0.555308
# 2      2  0.098989  0.950914 -1.327547  1.611558 -1.116051
# 3      3  0.819936  0.377387  0.739998  0.491142 -0.098866
# 4      4  0.538197 -1.152696 -1.035984  0.574331 -0.538455

# %% [markdown]
# # Plot
# Create/Feed a Series or DataFrame, and plot it simply by using ```plot()```
#
# The entire parameter list for `plot` is:
#
# `DataFrame.plot(data, x=None, y=None, kind='line', ax=None, subplots=False, sharex=True, sharey=False, layout=None, figsize=None, use_index=True, title=None, grid=None, legend=True, style=None, logx=False, logy=False, loglog=False, xticks=None, yticks=None, xlim=None, ylim=None, rot=None, fontsize=None, colormap=None, table=False, yerr=None, xerr=None, secondary_y=False, sort_columns=False, **kwds)`
#
# **Note**: Pandas uses matplotlib to render plots, so you must setup matplotlib.

# %%
#<help:plot_series>
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import numpy as np

# use default pandas formatting
pd.options.display.mpl_style = 'default'

s = pd.Series([1,4,3,6,5,8])
s.plot()
plt.show()
# Out:
# /usr/local/lib/python2.7/dist-packages/matplotlib/font_manager.py:1236: UserWarning: findfont: Font family ['monospace'] not found. Falling back to Bitstream Vera Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
#<help:plot_dataframe>
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import numpy as np

# use default pandas formatting
pd.options.display.mpl_style = 'default'

dates = pd.date_range('20140102',periods=4)
df = pd.DataFrame(np.random.randn(4,5),index=dates,columns=list('ABCDE'))
df.plot()
plt.show()

# %% [markdown]
# Select a column to plot only that column in a DataFrame.

# %%
#<help:plot_dataframe_col>
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import numpy as np

# use default pandas formatting
pd.options.display.mpl_style = 'default'

dates = pd.date_range('20140102',periods=4)
df = pd.DataFrame(np.random.randn(4,5),index=dates,columns=list('ABCDE'))
df['A'].plot()
plt.show()

# %% [markdown]
# The kind keyword argument of plot() accepts a handful of values for plots other than the default line plot. These include:
#
# * `'bar'` or `'barh'` for bar plots
#
# * `'box'` for boxplot
#
# * `'kde'` or `'density'` for density plots
#
# * `'area'` for area plots
#
# * `'scatter'` for scatter plots
#
# * `'hexbin'` for hexagonal bin plots
#
# * `.hist()` for histogram
#
# * `.pie()`  for pie plots

# %% [markdown]
# ## Scatter Plot

# %%
#<help:plot_scatter>
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import numpy as np

dates = pd.date_range('20140102',periods=6)
df = pd.DataFrame(np.random.randn(6,6),index=dates,columns=list('ABCDEF'))
df.plot(kind='scatter', x= 'A', y='B', color = 'g')
plt.show()

# %% [markdown]
# Scatter plot of multiple DataFrame columns.

# %%
#<help:plot_multiple_scatter>
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import numpy as np

df = pd.DataFrame(np.random.rand(25, 4), columns=['A', 'B', 'C', 'D'])
ax = df.plot(kind='scatter', x='A', y='D',
             color='Blue', label='Group 1')
df.plot(kind='scatter', x='B', y='C',
        color='Green', label='Group 2', ax=ax)
plt.show()

# %% [markdown]
# ## Bar Plot
# `kind='bar'`

# %%
#<help:plot_bar>
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import numpy as np

dates = pd.date_range('20141102',periods=8)
df = pd.DataFrame(np.random.randn(8,8),index=dates,columns=list('ABCDEFGH'))

df.plot(kind='bar', x= 'C', y='B', color='c')
plt.show()

# %% [markdown]
# ## Stacked Bar Plot
# `kind='bar'`
#
# `stacked='True'`

# %%
#<help:plot_bar_stacked>
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import numpy as np

df= pd.DataFrame(np.random.rand(10,4), columns=['a','b','c','d'])
df.plot(kind='bar', stacked='True')
plt.show()

# %% [markdown]
# ## Horizontal Bar Plot
# `kind='barh'`

# %%
#<help:plot_bar_horizontal>
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import numpy as np

dates = pd.date_range('20140902',periods=8)
df = pd.DataFrame(np.random.randn(8,8),index=dates,columns=list('ABCDEFGH'))
df.plot(kind='barh', x= 'C', y='F')
plt.show()

# %% [markdown]
# ## Density Plot
# ```kind='kde'```

# %%
#<help:plot_kde_density>
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import numpy as np

ser = pd.Series(np.random.randn(1000))
ser.plot(kind='kde')
plt.show()

# %% [markdown]
# ## Histogram
# `.hist()`

# %%
#<help:plot_hist>  

import matplotlib.pyplot as plt  
# %matplotlib inline  
import pandas as pd
import numpy as np  

s = pd.Series(np.random.randn(1000))  
s.hist()
plt.show()

# %% [markdown]
# ## Histogram (pandas 0.15.0)
# `kind='hist'`

# %% [markdown]
# A histogram can be stacked using `stacked=True`. The bin size can be customized by setting `bins=N`.

# %%
#<help:plot_hist_stacked>
from functools import wraps
def check_pandas_version(major=0, minor=0, fix=0):
    '''Decorator that checks for minimum version of pandas.'''
    def wrap(func):
        @wraps(func)
        def wrapped_func(*args, **kwargs):
            version = [int(x) for x in pd.version.version.split('.')]
            if version[0] < major or (version [0] == major and version[1] < minor) or \
               (version[0] == major and version[1] == minor and version[2] < fix):
                print 'Please upgrade your pandas installation to {}.{}.{} or later.' \
                    .format(major, minor, fix)
                return
            return func(*args, **kwargs)
        return wrapped_func
    return wrap

# %%
#<help:plot_hist_stacked>
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import numpy as np

df = pd.DataFrame({'A': np.random.randn(500) + 1, 'B': np.random.randn(500), 
                 'C': np.random.randn(500) - 1}, columns=['A', 'B', 'C'])

# kind=hist requires pandas 0.15 or later
@check_pandas_version(0, 15)
def plot():
    df.plot(kind='hist', stacked=True, bins=25)

plot()
plt.show()

# %% [markdown]
# Other keywords can be used, like `orientation='horizontal'` and `cumulative=True`

# %%
#<help:plot_hist_cumulative_horizontal>
from functools import wraps
def check_pandas_version(major=0, minor=0, fix=0):
    '''Decorator that checks for minimum version of pandas.'''
    def wrap(func):
        @wraps(func)
        def wrapped_func(*args, **kwargs):
            version = [int(x) for x in pd.version.version.split('.')]
            if version[0] < major or (version [0] == major and version[1] < minor) or \
               (version[0] == major and version[1] == minor and version[2] < fix):
                print 'Please upgrade your pandas installation to {}.{}.{} or later.' \
                    .format(major, minor, fix)
                return
            return func(*args, **kwargs)
        return wrapped_func
    return wrap

# %%
#<help:plot_hist_cumulative_horizontal>
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import numpy as np

df = pd.DataFrame({'A': np.random.randn(500) + 1, 'B': np.random.randn(500), 
                 'C': np.random.randn(500) - 1}, columns=['A', 'B', 'C'])

# kind=hist requires pandas 0.15 or later
@check_pandas_version(0, 15)
def plot():
    df['A'].plot(kind='hist', orientation='horizontal', cumulative=True)

plot()
plt.show()

# %% [markdown]
# ## Hexbin Plot (pandas 0.15.0)
#
# `kind='hexbin'`
#
# Useful for when a scatter plot has too many data points.
#
# Control the number of hexagons in the x direction with `gridsize`, defaults to 100.

# %%
#<help:plot_hexbin>
from functools import wraps
def check_pandas_version(major=0, minor=0, fix=0):
    '''Decorator that checks for minimum version of pandas.'''
    def wrap(func):
        @wraps(func)
        def wrapped_func(*args, **kwargs):
            version = [int(x) for x in pd.version.version.split('.')]
            if version[0] < major or (version [0] == major and version[1] < minor) or \
               (version[0] == major and version[1] == minor and version[2] < fix):
                print 'Please upgrade your pandas installation to {}.{}.{} or later.' \
                    .format(major, minor, fix)
                return
            return func(*args, **kwargs)
        return wrapped_func
    return wrap

# %%
#<help:plot_hexbin>
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import numpy as np

df = pd.DataFrame(np.random.rand(900, 3), columns=['A', 'B', 'C'])
df['B'] = df['B'] + np.arange(900)

# kind=hexbin requires pandas 0.15 or later
@check_pandas_version(0, 15)
def plot():
    df.plot(kind='hexbin', x='C', y='B', gridsize=20)
    
plot()
plt.show()

# %% [markdown]
# ## Scatter Plot for a Series

# %%
#<help:plot_scatter_series>
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd

np.random.seed(1974)

# Generate Data
num = 20
x, y = np.random.random((2, num))
labels = np.random.choice(['a', 'b', 'c'], num)
df = pd.DataFrame(dict(x=x, y=y, label=labels))

groups = df.groupby('label')

# Plot
fig, ax = plt.subplots()
ax.margins(0.05) # Optional, just adds 5% padding to the autoscaling
for name, group in groups:
    ax.plot(group.x, group.y, marker='o', linestyle='', ms=12, label=name)
ax.legend()
plt.show()

# %% [markdown]
# ## Box Plot
# ```.boxplot()```

# %%
#<help:plot_boxplot>
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd

daf = pd.DataFrame(np.random.rand(10,5))
bp= daf.boxplot()
plt.show()
# Out:
# /home/notebook/ka_env/lib/python2.7/site-packages/pandas/tools/plotting.py:2625: FutureWarning:
# The default value for 'return_type' will change to 'axes' in a future release.
#  To use the future behavior now, set return_type='axes'.
#  To keep the previous behavior and silence this warning, set return_type='dict'.
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## Bootstrap Plot
# These visually assess the uncertainty of a statistic.

# %%
#<help:plot_bootstrap_series>
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd
from pandas.tools.plotting import bootstrap_plot

data = pd.Series(np.random.rand(1500))
bootstrap_plot(data, size=50, samples= 300, color='m')
plt.show()

# %% [markdown]
# ## Pie Chart (pandas 0.15.0)
# `kind='pie'`
#
# **Note:**
# Use the `labels` and `colors` keywords to specify the labels and colors of each wedge.
# (Note the lack of “s” on those). This is to be consistent with `matplotlib.pyplot.pie()`.

# %%
#<help:plot_pie_chart>
from functools import wraps
def check_pandas_version(major=0, minor=0, fix=0):
    '''Decorator that checks for minimum version of pandas.'''
    def wrap(func):
        @wraps(func)
        def wrapped_func(*args, **kwargs):
            version = [int(x) for x in pd.version.version.split('.')]
            if version[0] < major or (version [0] == major and version[1] < minor) or \
               (version[0] == major and version[1] == minor and version[2] < fix):
                print 'Please upgrade your pandas installation to {}.{}.{} or later.' \
                    .format(major, minor, fix)
                return
            return func(*args, **kwargs)
        return wrapped_func
    return wrap

# %%
#<help:plot_pie_chart>
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd

series = pd.Series(3* np.random.rand(4), index=['a','b','c','d'], name='Series')

# kind=pie requires pandas 0.15 or later
@check_pandas_version(0, 15)
def plot():
    series.plot(kind='pie', labels=['AA', 'BB', 'CC', 'DD'], colors=['m', 'g', 'y', 'c'], figsize=(6,6))

plot()
plt.show()

# %% [markdown]
# ## Area Plot (pandas 0.15.0)
# `kind='area'`
#
# Stacked area chart.

# %%
#<help:plot_area_stacked>
from functools import wraps
def check_pandas_version(major=0, minor=0, fix=0):
    '''Decorator that checks for minimum version of pandas.'''
    def wrap(func):
        @wraps(func)
        def wrapped_func(*args, **kwargs):
            version = [int(x) for x in pd.version.version.split('.')]
            if version[0] < major or (version [0] == major and version[1] < minor) or \
               (version[0] == major and version[1] == minor and version[2] < fix):
                print 'Please upgrade your pandas installation to {}.{}.{} or later.' \
                    .format(major, minor, fix)
                return
            return func(*args, **kwargs)
        return wrapped_func
    return wrap

# %%
#<help:plot_area_stacked>
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd

df = pd.DataFrame(np.random.rand(10,4), columns=['a', 'b', 'c', 'd'])

# kind=area requires pandas 0.15 or later
@check_pandas_version(0, 15)
def plot():
    df.plot(kind='area')

plot()
plt.show()

# %% [markdown]
# Create unstacked are plot with `kind='area'` and `stacked=False`.

# %%
#<help:plot_area_unstacked>
from functools import wraps
def check_pandas_version(major=0, minor=0, fix=0):
    '''Decorator that checks for minimum version of pandas.'''
    def wrap(func):
        @wraps(func)
        def wrapped_func(*args, **kwargs):
            version = [int(x) for x in pd.version.version.split('.')]
            if version[0] < major or (version [0] == major and version[1] < minor) or \
               (version[0] == major and version[1] == minor and version[2] < fix):
                print 'Please upgrade your pandas installation to {}.{}.{} or later.' \
                    .format(major, minor, fix)
                return
            return func(*args, **kwargs)
        return wrapped_func
    return wrap

# %%
#<help:plot_area_unstacked>
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd

df = pd.DataFrame(np.random.rand(10,4), columns=['a', 'b', 'c', 'd'])

# kind=area requires pandas 0.15 or later
@check_pandas_version(0, 15)
def plot():
    df.plot(kind='area', stacked=False)

plot()
plt.show()

# %% [markdown]
# # Subplots
#
# Each Series in a DataFrame can be plotted on a different axis with the `subplots` keyword:
#
# ```df.plot(subplots=True, figsize=(6, 6));```

# %% [markdown]
# ## Line Plot

# %%
#<help:plot_subplots_line>
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd

df = pd.DataFrame(np.random.randn(100, 4), columns=list('ABCD'))
df.plot(subplots=True, figsize=(6, 6));
plt.show()

# %% [markdown]
# ## Histogram

# %%
#<help:plot_subplots_hist>
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd
pd.options.display.mpl_style = 'default'
df = pd.DataFrame({'A': np.random.randn(1000) + 1, 'B': np.random.randn(1000), 
                   'C': np.random.randn(1000) - 1}, columns = ['A','B','C'])
df.diff().hist(color='r', alpha=0.5, bins=30)
plt.show()

# %% [markdown]
# ## Stratified Boxplot
# Use the `by` keyword to create groupings.

# %%
#<help:plot_subplots_boxplot_stratified>
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd

df = pd.DataFrame(np.random.rand(10,2), columns=['Column1','Column2'])
df['X']= pd.Series(['A','A','A','A','A','B','B','B','B','B'])
bp = df.boxplot(by = 'X')
plt.show()

# %% [markdown]
# ## Scatter Matrix
# You can create a scatter plot matrix using the ```scatter_matrix``` method in pandas.tools.plotting.

# %%
#<help:plot_scatter_matrix>
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd

from pandas.tools.plotting import scatter_matrix
df = pd.DataFrame(np.random.randn(1000, 4), columns=['a', 'b', 'c', 'd'])
scatter_matrix(df, alpha=0.2, figsize=(6, 6), diagonal='kde')
plt.show()

# %% [markdown]
# ## Bar Chart
# From
# https://datasciencelab.wordpress.com/2013/12/21/beautiful-plots-with-pandas-and-matplotlib/

# %%
#<help:plot_subplots_bar>
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib.colors import LinearSegmentedColormap
from matplotlib.lines import Line2D 
 
countries = ['France','Spain','Sweden','Germany','Finland','Poland','Italy',
             'United Kingdom','Romania','Greece','Bulgaria','Hungary',
             'Portugal','Austria','Czech Republic','Ireland','Lithuania','Latvia',
             'Croatia','Slovakia','Estonia','Denmark','Netherlands','Belgium']
extensions = [547030,504782,450295,357022,338145,312685,301340,243610,238391,
              131940,110879,93028,92090,83871,78867,70273,65300,64589,56594,
              49035,45228,43094,41543,30528]
populations = [63.8,47,9.55,81.8,5.42,38.3,61.1,63.2,21.3,11.4,7.35,
               9.93,10.7,8.44,10.6,4.63,3.28,2.23,4.38,5.49,1.34,5.61,
               16.8,10.8]
life_expectancies = [81.8,82.1,81.8,80.7,80.5,76.4,82.4,80.5,73.8,80.8,73.5,
                    74.6,79.9,81.1,77.7,80.7,72.1,72.2,77,75.4,74.4,79.4,81,80.5]
data = {'Extension' : pd.Series(extensions, index=countries), 
        'Population' : pd.Series(populations, index=countries),
        'Life Expectancy' : pd.Series(life_expectancies, index=countries)}
 
df = pd.DataFrame(data)
df = df.sort('Life Expectancy')
fig, axes = plt.subplots(nrows=3, ncols=1)
for i, c in enumerate(df.columns):
    df[c].plot(kind='bar', ax=axes[i], figsize=(12, 10), title=c)
fig.tight_layout()    
plt.show()

# %% [markdown]
# ## Pie Charts (pandas 0.15.0)
# `subplots=True`

# %%
#<help:plot_subplots_pie>
from functools import wraps
def check_pandas_version(major=0, minor=0, fix=0):
    '''Decorator that checks for minimum version of pandas.'''
    def wrap(func):
        @wraps(func)
        def wrapped_func(*args, **kwargs):
            version = [int(x) for x in pd.version.version.split('.')]
            if version[0] < major or (version [0] == major and version[1] < minor) or \
               (version[0] == major and version[1] == minor and version[2] < fix):
                print 'Please upgrade your pandas installation to {}.{}.{} or later.' \
                    .format(major, minor, fix)
                return
            return func(*args, **kwargs)
        return wrapped_func
    return wrap

# %%
#<help:plot_subplots_pie>
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd

df = pd.DataFrame(3 * np.random.rand(4, 2), index=['a', 'b', 'c', 'd'], columns=['x', 'y'])

# kind=pie requires pandas 0.15 or later
@check_pandas_version(0, 15)
def plot():
    df.plot(kind='pie', subplots=True, labels=['A', 'B', 'C', 'D'], colors=['b', 'g', 'r', 'y'], figsize=(8,4))

plot()    
plt.show()

# %% [markdown]
# ## Groupby Bar Chart
#
# Group data and plot it in a bar chart. CSV file and code taken from:
#
# https://github.com/jvns/pandas-cookbook/blob/v0.1/data/bikes.csv

# %%
# !wget https://raw.githubusercontent.com/jvns/pandas-cookbook/v0.1/data/bikes.csv
# Out:
# --2015-03-25 15:21:09--  https://raw.githubusercontent.com/jvns/pandas-cookbook/v0.1/data/bikes.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 23.235.39.133
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|23.235.39.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13807 (13K) [text/plain]
# Saving to: ‘bikes.csv.2’
#
# 100%[======================================>] 13,807      --.-K/s   in 0.01s
#
# 2015-03-25 15:21:10 (903 KB/s) - ‘bikes.csv.2’ saved [13807/13807]

# %%
#<help:plot_groupby_bar>
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

bikes = pd.read_csv('bikes.csv',
                    sep=';', encoding='latin1',
                    parse_dates=['Date'], dayfirst=True,
                    index_col='Date')
# Add the weekday column
bikes['weekday'] = bikes.index.weekday
berri_bikes = bikes[['weekday','Berri 1']]

# Add up the number of cyclists by weekday, and plot!
weekday_counts = berri_bikes.groupby('weekday').aggregate(sum)
weekday_counts.index = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
weekday_counts.plot(kind='bar')
plt.show()

# %% [markdown]
# ## Groupby Line Plot

# %%
#<help:plot_groupby_line>
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import numpy as np

dates = pd.date_range('20140102',periods=4)
df = pd.DataFrame(np.random.randn(4,5), index=dates, columns=list('ABCDE'))
df = df.groupby('B').cumsum()
df.plot()
plt.show()

# %% [markdown]
# # Plot Formatting
#
# Title:
# * `plt.title('My Title')`
#
# Axis labels:
# * `plt.xlabel('xlabel')`
# * `plt.ylabel('ylabel')`
#
# You can customize `fontsize` and `color`.

# %%
#<help:plot_formatting_title_color>
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import numpy as np

dates = pd.date_range('20141102',periods=5)
df = pd.DataFrame(np.random.randn(5,5),index=dates,columns=list('ABCDE'))
df['A'].plot(color='g')

plt.title('My Title', fontsize=20)

plt.xlabel('X Axis', fontsize=16, color='r')
plt.ylabel('Y Axis', fontsize=16, color ='m')
plt.show()

# %% [markdown]
# ## Add Table (pandas 0.14.0)
#
# `table=[DataFrame] or [Series]`

# %%
#<help:plot_table>
from functools import wraps
def check_pandas_version(major=0, minor=0, fix=0):
    '''Decorator that checks for minimum version of pandas.'''
    def wrap(func):
        @wraps(func)
        def wrapped_func(*args, **kwargs):
            version = [int(x) for x in pd.version.version.split('.')]
            if version[0] < major or (version [0] == major and version[1] < minor) or \
               (version[0] == major and version[1] == minor and version[2] < fix):
                print 'Please upgrade your pandas installation to {}.{}.{} or later.' \
                    .format(major, minor, fix)
                return
            return func(*args, **kwargs)
        return wrapped_func
    return wrap

# %%
#<help:plot_table>
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import numpy as np

fig, ax = plt.subplots(1, 1)
ax.get_xaxis().set_visible(False)   # Hide Ticks
plt.title('Table at the Bottom')

df = pd.DataFrame(np.random.rand(5, 3), columns=['A', 'B', 'C'])

# table keyword added in pandas 0.14
@check_pandas_version(0, 14)
def plot():
    df.plot(table=np.round(df.T, 2), ax=ax)

plot()
plt.show()
# Out:
# Please upgrade your pandas installation to 0.14.0 or later.

# %% [markdown]
# ## Add Legend
# Use `plt.legend('My Legend', loc='best')` to add a legend.
#
# Remove a legend by setting `df.plot(legend=None)`.

# %%
#<help:plot_formatting_legend>
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))

df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index,
             columns=['A', 'B', 'C', 'D'])
df = df.cumsum()
df.plot()
plt.title('With Title')
plt.legend(loc='best')

# %% [markdown]
# ## Colormap
# Having many data sets when plotting serie makes it hard to distiguish them from each other. A colormap helps contrast the colors avoiding repetition. Use the [colormap](http://wiki.scipy.org/Cookbook/Matplotlib/Show_colormaps) hues to better differentiate data.

# %%
#<help:plot_formatting_colormap>
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

df = pd.DataFrame(np.random.randn(1000, 10))
df = df.cumsum()
df.plot(colormap='Set1')
plt.title('Set1 Colormap')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ## Log-Scale Axis
# Use  `logy`, or `logx` or `loglog=True` to get a log scale in the each or both axes (in the case of loglog).

# %%
#<help:plot_formatting_log_axes>
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

ts = pd.Series(np.random.randn(2000))
ts = np.exp(ts.cumsum())
ts.plot(logy=True)
plt.show()

# %% [markdown]
# ## Want to learn more?

# %% [markdown]
# <a href="http://bigdatauniversity.com/courses/python-for-data-analysis/?utm_source=tutorial-pandas-cookbook&utm_medium=dswb&utm_campaign=bdu"><img src = "https://ibm.box.com/shared/static/nw8w4ssxilysjzz1i49ygdrm8x1en6qw.png"> </a>

# %% [markdown]
# Created by: <a href="https://bigdatauniversity.com/?utm_source=bducreatedbylink&utm_medium=dswb&utm_campaign=bdu">The Cognitive Class Team</a>
